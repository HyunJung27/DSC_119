# %%
import pandas as pd
import numpy as np
import seaborn as sns
import folium

# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats

#Window 한글 폰트 설정
plt.rc('font', family='Malgun Gothic')

# %%
#Pandas로 scatter plot 그리기
# plt.figure(figsize=(10, 7))
fire_station.plot.scatter(x='X좌표', y='Y좌표')

# %% [markdown]
# # 119안전센터

# %%
spot119 = pd.read_csv('spot119.csv')
spot119
# Out:
#      고유번호     센터ID        센터명         위도          경도
# 0      21  1121101  양천119안전센터  37.527161  126.869452
# 1      22  1122101  신내119안전센터  37.610246  127.096473
# 2      42  1115104  서초119안전센터  37.487773  127.017145
# 3       3  1106102  이촌119안전센터  37.527841  126.958318
# 4       4  1106104  후암119안전센터  37.544896  126.981242
# ..    ...      ...        ...        ...         ...
# 112   117  1105105  금호119안전센터  37.545841  127.024530
# 113   106  1114401  삼성119안전센터  37.510765  127.056252
# 114   107  1114103  영동119안전센터  37.520161  127.027564
# 115   108  1111105  수락119안전센터  37.675376  127.066846
# 116   109  1119104  구로119안전센터  37.496988  126.887320
#
# [117 rows x 5 columns]

# %%
#Pandas로 scatter plot 그리기
# plt.figure(figsize=(10, 7))
spot119.plot.scatter(x='경도', y='위도')

# %% [markdown]
# # geopandas

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

#plt.rcParams["font.family"] = 'NanumGothic'
plt.rc('font', family='Malgun Gothic')
plt.rcParams["font.size"] = 13
plt.rcParams["figure.figsize"] = (10,10)

# %%
# seoul_file = "C:\Users\rkack\Downloads\SIG_201905.shp"
korea = gpd.read_file('TL_SCCO_SIG.shp', encoding='cp949')
# seoul = korea['SIG_KOR_NM']
seoul = korea.loc[0:24]
seoul
# Out:
#    SIG_CD       SIG_ENG_NM SIG_KOR_NM  \
# 0   11110        Jongno-gu        종로구
# 1   11140          Jung-gu         중구
# 2   11170       Yongsan-gu        용산구
# 3   11200     Seongdong-gu        성동구
# 4   11215      Gwangjin-gu        광진구
# 5   11230    Dongdaemun-gu       동대문구
# 6   11260      Jungnang-gu        중랑구
# 7   11290      Seongbuk-gu        성북구
# 8   11305       Gangbuk-gu        강북구
# 9   11320        Dobong-gu        도봉구
# 10  11350         Nowon-gu        노원구
# 11  11380     Eunpyeong-gu        은평구
# 12  11410     Seodaemun-gu       서대문구
# 13  11440          Mapo-gu        마포구
# 14  11470     Yangcheon-gu        양천구
# 15  11500       Gangseo-gu        강서구
# 16  11530          Guro-gu        구로구
# 17  11545     Geumcheon-gu        금천구
# 18  11560  Yeongdeungpo-gu       영등포구
# 19  11590       Dongjak-gu        동작구
# 20  11620        Gwanak-gu        관악구
# 21  11650        Seocho-gu        서초구
# 22  11680       Gangnam-gu        강남구
# ...

# %%
seoul.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
# SIG_CD        25 non-null object
# SIG_ENG_NM    25 non-null object
# SIG_KOR_NM    25 non-null object
# geometry      25 non-null geometry
# dtypes: geometry(1), object(3)
# memory usage: 928.0+ bytes

# %%
ax = seoul.convex_hull.plot(color='orange', edgecolor="white")
ax.set_title("서울특별시 자치구")
ax.set_axis_off()
plt.show()

# %%
convex_hull.plot?
# Out:
# Object `convex_hull.plot` not found.

# %%
location = pd.read_csv('spot119.csv')
location
# Out:
#      고유번호     센터ID        센터명         위도          경도
# 0      21  1121101  양천119안전센터  37.527161  126.869452
# 1      22  1122101  신내119안전센터  37.610246  127.096473
# 2      42  1115104  서초119안전센터  37.487773  127.017145
# 3       3  1106102  이촌119안전센터  37.527841  126.958318
# 4       4  1106104  후암119안전센터  37.544896  126.981242
# ..    ...      ...        ...        ...         ...
# 112   117  1105105  금호119안전센터  37.545841  127.024530
# 113   106  1114401  삼성119안전센터  37.510765  127.056252
# 114   107  1114103  영동119안전센터  37.520161  127.027564
# 115   108  1111105  수락119안전센터  37.675376  127.066846
# 116   109  1119104  구로119안전센터  37.496988  126.887320
#
# [117 rows x 5 columns]

# %%
from shapely.geometry import Point
crs = {'init':'epsg:4326'}

# %%
geometry = [Point(xy) for xy in zip(location['경도'], location['위도'])]
geometry[:3]

# %%
geo_df = gpd.GeoDataFrame(location, crs = crs, geometry = geometry)
geo_df.head()
# Out:
#    고유번호     센터ID        센터명         위도          경도                    geometry
# 0    21  1121101  양천119안전센터  37.527161  126.869452  POINT (126.86945 37.52716)
# 1    22  1122101  신내119안전센터  37.610246  127.096473  POINT (127.09647 37.61025)
# 2    42  1115104  서초119안전센터  37.487773  127.017145  POINT (127.01714 37.48777)
# 3     3  1106102  이촌119안전센터  37.527841  126.958318  POINT (126.95832 37.52784)
# 4     4  1106104  후암119안전센터  37.544896  126.981242  POINT (126.98124 37.54490)

# %%
ax2 = seoul.plot(color='orange', edgecolor='white')
ax2.set_title("서울특별시 자치구 별 119안전센터")
#geo_df.plot(ax=ax, color='red', markersize=10, marker="o")
ax2.set_axis_off()
plt.show()

# %%
seoul.crs = {'init':'epsg:4326'}
seoul.crs
# Out:
# {'init': 'epsg:4326'}

# %%
seoul.plot(color='orange', edgecolor='white')

# %%
seoul.geometry.name
# Out:
# 'geometry'

# %% [markdown]
# # 서울특별시 지도

# %%
seoul_h_dong_gdf = gpd.read_file('seoul_h_dong.shp', encoding='utf-8')
seoul_h_dong_gdf
# Out:
#     SGG_NM DONG_NM SGG_CODE   H_CODE  SEDAE  SEDAE_INGU  TOTAL_POP  MALE_POP  \
# 0      종로구     사직동    11110  1111000   4414        2.14       9717      4467
# 1      종로구     삼청동    11110  1111000   1414        2.06       3097      1459
# 2      종로구     부암동    11110  1111000   4325        2.39      10726      5160
# 3      종로구     평창동    11110  1111000   7510        2.53      19163      9032
# 4      종로구     무악동    11110  1111000   3024        2.75       8375      3921
# ..     ...     ...      ...      ...    ...         ...        ...       ...
# 419    강동구    둔촌1동    11740  1174000    888        2.21       1997      1035
# 420    강동구    둔촌2동    11740  1174000  11126        2.59      28920     14355
# 421    강동구    암사1동    11740  1174000  16345        2.33      38434     19153
# 422    강동구    천호2동    11740  1174000  17305        2.08      36691     18428
# 423    강동구      길동    11740  1174000  21066        2.38      50423     24814
#
# ...

# %%
seoul_h_dong_gdf.crs = {'init':'epsg:4326'}
seoul_h_dong_gdf.crs
# Out:
# {'init': 'epsg:4326'}

# %%
seoul_h_dong_gdf.plot(color='orange', edgecolor='white')
